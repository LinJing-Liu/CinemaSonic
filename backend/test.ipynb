# %%
import nltk
import pandas as pd
import numpy as np
from ast import literal_eval

# %%
movies_df = pd.read_csv("clean_movie_dataset.csv")

# %%
new_df = pd.read_pickle("clean_movie_dataset.pkl")

# %%
for lst in new_df['genre']:
  print(lst)
  print(type(lst))
# Out:
# ['drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama', 'western']
# <class 'list'>
# ['adventure', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['adventure', 'drama', 'war']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['crime', 'drama', 'fantasy']
# <class 'list'>
# ['biography', 'comedy', 'crime']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'family']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['drama', 'romance', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'drama']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['adventure', 'fantasy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['drama', 'horror']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['sci-fi', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['horror', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['crime', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'fantasy', 'mystery']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['adventure', 'western']
# <class 'list'>
# ['biography', 'comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'drama', 'music']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['adventure', 'fantasy']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['adventure', 'comedy', 'crime']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['adventure', 'drama', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'war']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['biography', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['mystery', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['adventure', 'mystery', 'sci-fi']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'mystery', 'war']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['crime', 'mystery', 'thriller']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['adventure', 'drama', 'fantasy']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'biography', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['sci-fi', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'family']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['adventure', 'drama', 'thriller']
# <class 'list'>
# ['action', 'crime', 'mystery']
# <class 'list'>
# ['drama', 'music']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'horror']
# <class 'list'>
# ['adventure', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'romance', 'war']
# <class 'list'>
# ['action', 'mystery', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'comedy', 'horror']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy', 'fantasy']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['drama', 'history']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['drama', 'sci-fi', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'horror']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['drama', 'romance', 'sci-fi']
# <class 'list'>
# ['adventure', 'fantasy']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['action', 'comedy', 'mystery']
# <class 'list'>
# ['adventure', 'drama', 'fantasy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'war']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'thriller', 'war']
# <class 'list'>
# ['action', 'drama', 'sport']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['action', 'biography', 'crime']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'family']
# <class 'list'>
# ['comedy', 'fantasy']
# <class 'list'>
# ['action', 'mystery', 'sci-fi']
# <class 'list'>
# ['animation', 'family', 'fantasy']
# <class 'list'>
# ['action', 'comedy', 'war']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'drama', 'war']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['comedy', 'fantasy', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'mystery']
# <class 'list'>
# ['drama', 'horror', 'sci-fi']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'fantasy']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'mystery']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['drama', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'mystery', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['action', 'crime', 'sci-fi']
# <class 'list'>
# ['biography', 'drama', 'sport']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['drama', 'horror', 'musical']
# <class 'list'>
# ['adventure', 'family', 'sci-fi']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'western']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['drama', 'family', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'fantasy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['adventure', 'drama']
# <class 'list'>
# ['biography', 'drama', 'music']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'comedy', 'fantasy']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['fantasy', 'horror', 'mystery']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'drama', 'romance']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['horror', 'mystery', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['mystery', 'romance', 'thriller']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'family']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'musical', 'romance']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'western']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'horror']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['drama', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'fantasy', 'horror']
# <class 'list'>
# ['biography', 'drama', 'sport']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'biography', 'crime']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'musical', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['biography', 'drama', 'sport']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['animation', 'family', 'fantasy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'fantasy']
# <class 'list'>
# ['adventure', 'drama', 'fantasy']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['drama', 'sci-fi', 'thriller']
# <class 'list'>
# ['horror', 'sci-fi', 'thriller']
# <class 'list'>
# ['comedy', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['drama', 'romance', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'crime', 'horror']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['drama', 'history', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['western']
# <class 'list'>
# ['drama', 'romance', 'war']
# <class 'list'>
# ['action', 'crime', 'fantasy']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['animation', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'music', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'music']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['fantasy', 'horror', 'mystery']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['adventure', 'drama', 'history']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['action', 'fantasy', 'thriller']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['fantasy', 'mystery', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['action', 'crime', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['romance', 'sci-fi', 'thriller']
# <class 'list'>
# ['adventure', 'comedy', 'crime']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['comedy', 'fantasy', 'horror']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'horror']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['adventure', 'biography', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['crime', 'drama', 'history']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure']
# <class 'list'>
# ['crime', 'drama', 'fantasy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'comedy', 'thriller']
# <class 'list'>
# ['sci-fi', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'fantasy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'drama', 'war']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['biography', 'drama', 'music']
# <class 'list'>
# ['animation', 'drama', 'family']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'mystery', 'sci-fi']
# <class 'list'>
# ['drama', 'music']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['adventure', 'drama', 'western']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['adventure', 'drama', 'fantasy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'comedy', 'sci-fi']
# <class 'list'>
# ['comedy', 'sport']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'horror', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy']
# <class 'list'>
# ['drama', 'history', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'mystery']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'sci-fi']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'fantasy', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'fantasy']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['action', 'adventure', 'western']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['horror', 'thriller']
# <class 'list'>
# ['action', 'crime', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['biography', 'comedy', 'drama']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['drama', 'history', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime']
# <class 'list'>
# ['comedy', 'crime', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'history']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'music', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['biography', 'drama', 'family']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['drama', 'fantasy', 'horror']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['animation', 'action', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'sci-fi']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'crime', 'musical']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['animation', 'comedy', 'family']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'musical', 'romance']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['action', 'comedy', 'fantasy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['action', 'comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'romance', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'history']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['adventure', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'drama', 'sport']
# <class 'list'>
# ['animation', 'comedy', 'fantasy']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['biography', 'drama', 'sport']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['adventure', 'comedy', 'crime']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['adventure', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'fantasy', 'horror']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'fantasy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['horror', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['western']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['fantasy', 'mystery', 'sci-fi']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'comedy']
# <class 'list'>
# ['action', 'fantasy', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy', 'sport']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'horror', 'thriller']
# <class 'list'>
# ['adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['adventure', 'horror', 'thriller']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['biography', 'drama', 'family']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['drama', 'sci-fi']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['action', 'mystery', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['comedy', 'musical', 'romance']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['adventure', 'drama', 'war']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['biography', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['biography', 'drama', 'family']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['action', 'comedy', 'romance']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'music']
# <class 'list'>
# ['action', 'drama', 'western']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'fantasy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'musical', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'drama', 'sport']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['adventure', 'drama', 'history']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'fantasy', 'horror']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['biography', 'drama', 'war']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'music']
# <class 'list'>
# ['animation', 'drama', 'family']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['biography', 'comedy', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'horror', 'mystery']
# <class 'list'>
# ['drama', 'romance', 'war']
# <class 'list'>
# ['comedy', 'fantasy', 'horror']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama', 'music', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'family', 'fantasy']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['adventure', 'family', 'fantasy']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'horror']
# <class 'list'>
# ['drama', 'fantasy', 'horror']
# <class 'list'>
# ['drama', 'film-noir']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'fantasy']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['comedy', 'sci-fi']
# <class 'list'>
# ['drama', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'history', 'war']
# <class 'list'>
# ['action', 'biography', 'drama']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['action', 'drama', 'fantasy']
# <class 'list'>
# ['horror', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'drama', 'fantasy']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['animation', 'drama', 'war']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['mystery', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['comedy', 'drama', 'war']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'romance']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy', 'fantasy']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['drama', 'fantasy']
# <class 'list'>
# ['adventure', 'sci-fi']
# <class 'list'>
# ['action', 'comedy']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'western']
# <class 'list'>
# ['action', 'drama', 'sci-fi']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['fantasy', 'horror', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'biography']
# <class 'list'>
# ['biography', 'drama', 'thriller']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'family']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'horror', 'sci-fi']
# <class 'list'>
# ['adventure', 'drama', 'mystery']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'sport']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['action', 'comedy', 'thriller']
# <class 'list'>
# ['comedy', 'crime', 'sport']
# <class 'list'>
# ['comedy', 'sport']
# <class 'list'>
# ['horror', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'mystery']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'horror']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['drama', 'sci-fi']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['family', 'fantasy', 'musical']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'horror']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'crime', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'drama', 'family']
# <class 'list'>
# ['adventure', 'comedy', 'fantasy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['action', 'adventure', 'sci-fi']
# <class 'list'>
# ['drama', 'fantasy', 'thriller']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'fantasy', 'romance']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'horror', 'mystery']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['horror', 'thriller']
# <class 'list'>
# ['horror', 'sci-fi', 'thriller']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['action', 'fantasy', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'crime']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'drama', 'family']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'horror']
# <class 'list'>
# ...
# <class 'list'>
# ['action', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['crime', 'mystery', 'thriller']
# <class 'list'>
# ['animation', 'drama', 'family']
# <class 'list'>
# ['action', 'drama', 'fantasy']
# <class 'list'>
# ['action', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'sport']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['comedy', 'romance', 'sport']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['comedy', 'horror', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'thriller']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['action', 'drama', 'family']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['horror', 'sci-fi', 'thriller']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['action', 'sci-fi', 'thriller']
# <class 'list'>
# ['drama', 'romance', 'sport']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama']
# <class 'list'>
# ['animation', 'drama', 'family']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'western']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['crime', 'mystery', 'thriller']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'family']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['action', 'drama', 'war']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['drama', 'fantasy']
# <class 'list'>
# ['action', 'crime', 'fantasy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['drama', 'sci-fi', 'thriller']
# <class 'list'>
# ['biography', 'comedy', 'drama']
# <class 'list'>
# ['action', 'thriller']
# <class 'list'>
# ['comedy', 'family']
# <class 'list'>
# ['animation', 'comedy', 'musical']
# <class 'list'>
# ['drama', 'romance', 'sci-fi']
# <class 'list'>
# ['comedy', 'war']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'music']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'family', 'romance']
# <class 'list'>
# ['musical', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'family', 'fantasy']
# <class 'list'>
# ['drama', 'family', 'fantasy']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'thriller']
# <class 'list'>
# ['adventure', 'drama', 'history']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'romance', 'sport']
# <class 'list'>
# ['comedy', 'drama', 'history']
# <class 'list'>
# ['adventure', 'drama', 'family']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'family']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['horror', 'sci-fi']
# <class 'list'>
# ['action', 'horror', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['adventure', 'drama']
# <class 'list'>
# ['action', 'comedy', 'romance']
# <class 'list'>
# ['adventure', 'comedy', 'sci-fi']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'music', 'romance']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['adventure', 'biography', 'drama']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['comedy', 'drama', 'music']
# <class 'list'>
# ['action', 'drama', 'war']
# <class 'list'>
# ['comedy', 'crime', 'family']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['adventure', 'drama', 'horror']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['crime', 'drama', 'film-noir']
# <class 'list'>
# ['drama', 'music', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['adventure', 'fantasy', 'horror']
# <class 'list'>
# ['drama', 'romance', 'western']
# <class 'list'>
# ['adventure', 'drama', 'mystery']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['drama', 'history']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'sport']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'music']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['drama', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'history']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'horror']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'horror']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['comedy', 'drama', 'musical']
# <class 'list'>
# ['comedy', 'drama', 'sport']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['thriller', 'war']
# <class 'list'>
# ['drama', 'war']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['comedy', 'fantasy', 'horror']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'history', 'romance']
# <class 'list'>
# ['action', 'comedy']
# <class 'list'>
# ['comedy', 'romance', 'sci-fi']
# <class 'list'>
# ['drama', 'romance', 'thriller']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['adventure', 'drama']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['crime', 'horror', 'thriller']
# <class 'list'>
# ['drama', 'romance', 'western']
# <class 'list'>
# ['horror', 'mystery', 'sci-fi']
# <class 'list'>
# ['comedy', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'history', 'thriller']
# <class 'list'>
# ['action', 'comedy', 'fantasy']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'sci-fi']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['comedy', 'drama', 'war']
# <class 'list'>
# ['comedy', 'fantasy', 'horror']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'thriller']
# <class 'list'>
# ['drama', 'horror', 'romance']
# <class 'list'>
# ['horror', 'sci-fi']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'western']
# <class 'list'>
# ['animation', 'adventure', 'family']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['comedy', 'crime', 'romance']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'fantasy', 'horror']
# <class 'list'>
# ['adventure', 'romance', 'war']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['action', 'sci-fi', 'sport']
# <class 'list'>
# ['horror', 'mystery']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'fantasy', 'romance']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'musical']
# <class 'list'>
# ['comedy', 'horror', 'thriller']
# <class 'list'>
# ['action', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'horror', 'thriller']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['drama', 'history', 'war']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'musical']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['comedy', 'sci-fi']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['action', 'crime', 'thriller']
# <class 'list'>
# ['crime', 'horror', 'mystery']
# <class 'list'>
# ['animation', 'adventure', 'drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['adventure', 'horror']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['adventure', 'comedy']
# <class 'list'>
# ['biography', 'comedy', 'drama']
# <class 'list'>
# ['drama', 'history', 'war']
# <class 'list'>
# ['comedy', 'crime', 'thriller']
# <class 'list'>
# ['drama', 'film-noir', 'mystery']
# <class 'list'>
# ['drama', 'fantasy', 'horror']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'crime']
# <class 'list'>
# ['drama', 'fantasy', 'sci-fi']
# <class 'list'>
# ['action', 'crime', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'comedy', 'drama']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['comedy', 'crime', 'mystery']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'mystery', 'sci-fi']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'horror']
# <class 'list'>
# ['drama', 'horror']
# <class 'list'>
# ['crime', 'film-noir', 'thriller']
# <class 'list'>
# ['animation', 'comedy', 'fantasy']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['comedy', 'horror', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['biography', 'drama', 'sport']
# <class 'list'>
# ['adventure', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'horror', 'sci-fi']
# <class 'list'>
# ['action', 'fantasy', 'horror']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['drama', 'romance', 'thriller']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama', 'horror', 'mystery']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['crime', 'thriller']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['crime', 'drama', 'thriller']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['crime', 'horror', 'mystery']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['crime', 'drama', 'fantasy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['drama', 'mystery', 'romance']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['horror', 'mystery', 'thriller']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'mystery']
# <class 'list'>
# ['action', 'adventure', 'drama']
# <class 'list'>
# ['biography', 'drama']
# <class 'list'>
# ['action', 'adventure', 'horror']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'romance', 'sci-fi']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['animation', 'adventure', 'comedy']
# <class 'list'>
# ['drama', 'romance', 'western']
# <class 'list'>
# ['animation', 'action', 'adventure']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['horror', 'sci-fi', 'thriller']
# <class 'list'>
# ['comedy', 'musical', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'thriller', 'war']
# <class 'list'>
# ['horror', 'sci-fi']
# <class 'list'>
# ['action', 'comedy', 'family']
# <class 'list'>
# ['action', 'adventure', 'fantasy']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['drama', 'music', 'musical']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['horror', 'mystery', 'romance']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'romance']
# <class 'list'>
# ['drama', 'romance']
# <class 'list'>
# ['horror']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['adventure', 'drama', 'history']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['horror', 'thriller']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['drama', 'history']
# <class 'list'>
# ['comedy', 'family']
# <class 'list'>
# ['biography', 'drama', 'history']
# <class 'list'>
# ['biography', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'crime', 'romance']
# <class 'list'>
# ['comedy', 'crime', 'history']
# <class 'list'>
# ['crime', 'drama', 'romance']
# <class 'list'>
# ['adventure', 'comedy', 'family']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['action', 'drama', 'thriller']
# <class 'list'>
# ['action', 'biography', 'crime']
# <class 'list'>
# ['action', 'fantasy', 'romance']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'horror', 'mystery']
# <class 'list'>
# ['drama']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['comedy', 'horror']
# <class 'list'>
# ['drama', 'horror', 'thriller']
# <class 'list'>
# ['comedy', 'crime', 'drama']
# <class 'list'>
# ['adventure', 'biography', 'drama']
# <class 'list'>
# ['drama', 'thriller']
# <class 'list'>
# ['crime', 'horror', 'mystery']
# <class 'list'>
# ['romance', 'thriller']
# <class 'list'>
# ['action', 'adventure', 'comedy']
# <class 'list'>
# ['action', 'comedy', 'crime']
# <class 'list'>
# ['action', 'drama', 'history']
# <class 'list'>
# ['crime', 'drama']
# <class 'list'>
# ['biography', 'drama', 'fantasy']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy', 'drama']
# <class 'list'>
# ['comedy']
# <class 'list'>
# ['crime', 'drama', 'mystery']
# <class 'list'>
# ['action', 'crime', 'drama']
# <class 'list'>
# ['comedy', 'drama', 'musical']
# <class 'list'>
# ['comedy', 'romance']
# <class 'list'>
# ['comedy', 'drama', 'family']
# <class 'list'>
# ['drama', 'western']
# <class 'list'>

# %%
count
# Out:
# 0

# %%
movies_df['genre']

# %%
movies_df = pd.read_csv("clean_movie_dataset.csv", converters={'genre': pd.eval})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 movies_df = pd.read_csv("clean_movie_dataset.csv", converters={'genre': pd.eval})
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\_libs\parsers.pyx:883, in pandas._libs.parsers.TextReader._read_rows()
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\_libs\parsers.pyx:1005, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\_libs\parsers.pyx:2014, in pandas._libs.parsers._apply_converter()
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\core\computation\eval.py:355, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     353 eng = ENGINES[engine]
#     354 eng_inst = eng(parsed_expr)
# --> 355 ret = eng_inst.evaluate()
#     357 if parsed_expr.assigner is None:
#     358     if multi_line:
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\core\computation\engines.py:80, in AbstractEngine.evaluate(self)
#      77     self.result_type, self.aligned_axes = align_terms(self.expr.terms)
#      79 # make sure no names in resolvers and locals/globals clash
# ---> 80 res = self._evaluate()
#      81 return reconstruct_object(
#      82     self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#      83 )
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\pandas\core\computation\engines.py:121, in NumExprEngine._evaluate(self)
#     119 scope = env.full_scope
#     120 _check_ne_builtin_clash(self.expr)
# --> 121 return ne.evaluate(s, local_dict=scope)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\numexpr\necompiler.py:822, in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     819 arguments = getArguments(names, local_dict, global_dict)
#     821 # Create a signature
# --> 822 signature = [(name, getType(arg)) for (name, arg) in
#     823              zip(names, arguments)]
#     825 # Look up numexpr if possible.
#     826 numexpr_key = expr_key + (tuple(signature),)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\numexpr\necompiler.py:822, in <listcomp>(.0)
#     819 arguments = getArguments(names, local_dict, global_dict)
#     821 # Create a signature
# --> 822 signature = [(name, getType(arg)) for (name, arg) in
#     823              zip(names, arguments)]
#     825 # Look up numexpr if possible.
#     826 numexpr_key = expr_key + (tuple(signature),)
#
# File e:\Anaconda3\envs\law_project\lib\site-packages\numexpr\necompiler.py:699, in getType(a)
#     697     return bytes
#     698 if kind == 'U':
# --> 699     raise ValueError('NumExpr 2 does not support Unicode as a dtype.')
#     700 raise ValueError("unknown type %s" % a.dtype.name)
#
# ValueError: NumExpr 2 does not support Unicode as a dtype.

# %%
movies_df = movies_df[movies_df['genre'].notna()]

# %%
movies_df.to_csv('clean_movie_dataset.csv')

# %%
movies_df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           4
# ...            ...         ...
# 4981          4981        4981
# 4982          4982        4982
# 4983          4983        4983
# 4984          4984        4984
# 4985          4985        4985
#
#                                                  poster  \
# 0     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3     https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4     https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4981  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4982  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4983  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4984  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4985  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                 title certificate         runtime  \
# 0            the shawshank redemption          15         142 min
# 1                     the dark knight         12A         152 min
# 2                           inception         12A         148 min
# 3                          fight club          18         139 min
# 4                        pulp fiction          18         154 min
# ...                               ...         ...             ...
# 4981  seven brides for seven brothers           U         102 min
# 4982                  playing it cool          15          94 min
# 4983             a moment to remember     144 min  Drama, Romance
# 4984                        hairspray          PG          92 min
# 4985             mccabe & mrs. miller           X         120 min
#
#                                   genre  rating  \
# 0                             ['drama']     9.3
# 1          ['action', 'crime', 'drama']     9.0
# 2     ['action', 'adventure', 'sci-fi']     8.8
# 3                             ['drama']     8.8
# 4                    ['crime', 'drama']     8.9
# ...                                 ...     ...
# 4981     ['comedy', 'drama', 'musical']     7.3
# 4982              ['comedy', 'romance']     5.9
# 4983                                NaN     8.1
# 4984      ['comedy', 'drama', 'family']     7.0
# 4985               ['drama', 'western']     7.6
#
#                                                   about           director  \
# 0     Two imprisoned men bond over a number of years...     frank darabont
# 1     When the menace known as the Joker wreaks havo...  christopher nolan
# 2     A thief who steals corporate secrets through t...  christopher nolan
# 3     An insomniac office worker and a devil-may-car...      david fincher
# 4     The lives of two mob hitmen, a boxer, a gangst...  quentin tarantino
# ...                                                 ...                ...
# 4981  In 1850 Oregon, when a backwoodsman brings a w...      stanley donen
# 4982  Unrequited love motivates a guy to write about...     justin reardon
# 4983  A young couple's enduring love is tested when ...        john h. lee
# 4984  A 'pleasantly plump' teenager teaches 1962 Bal...        john waters
# 4985  A gambler and a prostitute become business par...      robert altman
#
#                                                   stars      votes gross_earn  \
# 0     ('Tim Robbins',), ('Morgan Freeman',), ('Bob G...  26,26,905    $28.34M
# 1     ('Christian Bale',), ('Heath Ledger',), ('Aaro...  25,98,173   $534.86M
# 2     ('Leonardo DiCaprio',), ('Joseph Gordon-Levitt...  23,04,062   $292.58M
# 3     ('Brad Pitt',), ('Edward Norton',), ('Meat Loa...  20,71,088    $37.03M
# 4     ('John Travolta',), ('Uma Thurman',), ('Samuel...  20,11,013   $107.93M
# ...                                                 ...        ...        ...
# 4981  ('Jane Powell',), ('Howard Keel',), ('Jeff Ric...     25,112     $9.40M
# 4982  ('Chris Evans',), ('Michelle Monaghan',), ('To...     28,515        NaN
# 4983  ('Jung Woo-sung',), ('Son Ye-jin',), ('Jong-ha...     23,957        NaN
# 4984  ('Sonny Bono',), ('Ruth Brown',), ('Divine',),...     21,536     $6.67M
# 4985  ('Warren Beatty',), ('Julie Christie',), ('Ren...     25,097     $8.20M
#
#                                             clean about
# 0     ['two', 'imprisoned', 'men', 'bond', 'number',...
# 1     ['menace', 'known', 'joker', 'wreaks', 'havoc'...
# 2     ['thief', 'steals', 'corporate', 'secrets', 'u...
# 3     ['insomniac', 'office', 'worker', 'devilmaycar...
# 4     ['lives', 'two', 'mob', 'hitmen', 'boxer', 'ga...
# ...                                                 ...
# 4981  ['1850', 'oregon', 'backwoodsman', 'brings', '...
# 4982  ['unrequited', 'love', 'motivates', 'guy', 'wr...
# 4983  ['young', 'couples', 'enduring', 'love', 'test...
# 4984  ['pleasantly', 'plump', 'teenager', 'teaches',...
# 4985  ['gambler', 'prostitute', 'become', 'business'...
#
# [4986 rows x 14 columns]

# %%
movies_df['genre'][1]
# Out:
# ['action', 'crime', 'drama']

# %%
movies_df.to_pickle("clean_movie_dataset.pkl")

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    movies_df['genre'][i] = obj.strip('][').split(', ')
# Out:
# C:\Users\quant\AppData\Local\Temp\ipykernel_35336\3382937815.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df['genre'][i] = obj.strip('][').split(', ')

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    for j in range(len(obj)):
      movies_df['genre'][i][j] = eval(obj[j])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 5
#       3 if type(obj) != float:
#       4   for j in range(len(obj)):
# ----> 5     movies_df['genre'][i][j] = eval(obj[j])
#
# File <string>:1
#
# NameError: name 'drama' is not defined

# %%
movies_df['genre'][1][0]
# Out:
# 'action'

# %%
type(movies_df['genre'][1][0])
# Out:
# str

# %%
movies_df
# Out:
# 0          frank darabont
# 1       christopher nolan
# 2       christopher nolan
# 3           david fincher
# 4       quentin tarantino
#               ...
# 4981        stanley donen
# 4982       justin reardon
# 4983          john h. lee
# 4984          john waters
# 4985        robert altman
# Name: director, Length: 4986, dtype: object

# %%
for i in range(len(movies_df['genre'])):
  obj = movies_df['genre'][i]
  if type(obj) != float:
    for j in range(len(obj)):
      movies_df['genre'][i][j] = obj[j].strip()

# %%
genre_lst = ["horror",
 "crime",
 "western",
"film-noir",
"sci-fi",
"adventure",
"mystery",
 "thriller",
 "comedy",
 "romance",
 "mystery",
"family",
"animation",
"western",
 "biography",
"crime",
 "sport",
 "fantasy",
"action",
 "war",
"drama",
 "musical",
 "music",
 "history"
]

# %%
genre_lst_df = pd.DataFrame(genre_lst,columns=['genres'])
genre_lst_df
# Out:
#        genres
# 0      horror
# 1       sport
# 2   film-noir
# 3         war
# 4   adventure
# 5     history
# 6      action
# 7       crime
# 8     musical
# 9       music
# 10     comedy
# 11    romance
# 12     sci-fi
# 13    fantasy
# 14  animation
# 15   thriller
# 16      drama
# 17    western
# 18     family
# 19  biography
# 20    mystery

# %%
genre_lst_df.to_pickle('genre_lst.pkl')

# %%
a = pd.read_pickle('genre_lst.pkl')['genres']

# %%
a = a.to_list()

# %%
a
# Out:
# ['horror',
#  'sport',
#  'film-noir',
#  'war',
#  'adventure',
#  'history',
#  'action',
#  'crime',
#  'musical',
#  'music',
#  'comedy',
#  'romance',
#  'sci-fi',
#  'fantasy',
#  'animation',
#  'thriller',
#  'drama',
#  'western',
#  'family',
#  'biography',
#  'mystery']

# %%
genre_lst_df.to_csv('genre_lst.csv')

# %%
movies_df['director'] = movies_df['director'].str.lower()

# %%
movies_df
# Out:
#                      track_id  \
# 0      004s3t0ONYlzxII9PLgU6z
# 1      00chLpzhgVjxs1zKC9UScL
# 2      00cqd6ZsSkLZqGMlQCR0Zo
# 3      00emjlCv9azBN0fzuuyLqy
# 4      00f9VGHfQhAHMCQ2bSjg3D
# ...                       ...
# 13407  7zU9pcTnh6Q4nBnrg47Xz0
# 13408  7zxLkZbUxITHabPzGN8Xgc
# 13409  7zxRMhXxJMQCeDDg0rKAVo
# 13410  7zXzWCVuz7whIuYZyEAlxt
# 13411  7zye9v6B785eFWEFYs13C2
#
#                                               track_name  \
# 0                                           I Feel Alive
# 1                                                 Poison
# 2      Baby It's Cold Outside (feat. Christina Aguilera)
# 3                                             Dumb Litty
# 4                                                Soldier
# ...                                                  ...
# 13407  Bubble Butt (feat. Bruno Mars, 2 Chainz, Tyga ...
# 13408                                       Sick Feeling
# 13409                                           Some Way
# 13410                    Rising Like The Sun - Radio Mix
# 13411                                              Bound
#
#                    track_artist  \
# 0                 Steady Rollin
# 1                Bell Biv DeVoe
# 2                   CeeLo Green
# 3                          KARD
# 4                      James TW
# ...                         ...
# 13407               Major Lazer
# 13408                 boy pablo
# 13409                       NAV
# 13410                   Qulinez
# 13411  Ponderosa Twins Plus One
#
#                                                   lyrics  track_popularity  \
# 0      ['the trees are singing in the wind', 'the sky...                28
# 1      ['n', 'a', 'yeah', 'spyderman and', 'freeze in...                 0
# 2      ['i really cant stay', 'baby its cold outside'...                41
# 3      ['get up out of my business', 'you dont keep m...                65
# 4      ['hold your breath dont look down keep trying'...                70
# ...                                                  ...               ...
# 13407  ['bubble butt bubble bubble bubble butt', 'bub...                 0
# 13408  ['i had to catch the bus', 'alarm was shaking ...                64
# 13409  ['yeah nah nah nah nah nah nah nah nah', 'nah ...                72
# 13410  ['caught up in such a head rush wideeyed latel...                 0
# 13411  ['bound bound', 'bound bound', 'bound to fall ...                40
#
#                track_album_id  \
# 0      3z04Lb9Dsilqw68SHt6jLB
# 1      6oZ6brjB8x3GoeSYdwJdPc
# 2      3ssspRe42CXkhPxdc12xcp
# 3      7h5X3xhh3peIK9Y0qI5hbK
# 4      3GNzXsFbzdwM0WKCZtgeNP
# ...                       ...
# 13407  18w3FsBQO332yxJpQvSWXh
# 13408  1lESM5Y1VAvrCLEgLmyfOw
# 13409  4JR29CNW14Zc4Z5vflxkoJ
# 13410  1l4aoukbPgi5u2OaE2R4Zj
# 13411  1xdgLmTFMSyJyI5DJOOX7T
#
#                                         track_album_name  \
# 0                                            Love & Loss
# 1                                                   Gold
# 2                                   CeeLo's Magic Moment
# 3                   KARD 2nd Digital Single ‘Dumb Litty’
# 4                                               Chapters
# ...                                                  ...
# 13407  Bubble Butt (Remix) (feat. Bruno Mars, 2 Chain...
# 13408                                          Soy Pablo
# 13409                                                NAV
# 13410                                Rising Like The Sun
# 13411                     2+2+1 = (Digitally Remastered)
#
#       track_album_release_date  \
# 0                   2017-11-21
# 1                   2005-01-01
# 2                   2012-10-29
# 3                   2019-09-22
# 4                   2019-04-26
# ...                        ...
# 13407               2013-05-31
# 13408               2018-10-05
# 13409               2017-02-24
# 13410               2014-03-24
# 13411               2013-07-09
#
#                                            playlist_name  \
# 0                                      Hard Rock Workout
# 1      Back in the day - R&B, New Jack Swing, Swingbe...
# 2                                         Christmas Soul
# 3                                      K-Party Dance Mix
# 4                                     urban contemporary
# ...                                                  ...
# 13407  Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Danc...
# 13408                                         ②⓪①⑨ mixed
# 13409                              PROJECT: Contemporary
# 13410                                    ♥ EDM LOVE 2020
# 13411                                     Sexy Soul 2020
#
#                   playlist_id  ... speechiness acousticness  instrumentalness  \
# 0      3YouF0u7waJnolytf9JCXf  ...      0.0442      0.01170          0.009940
# 1      3a9y4eeCJRmG9p4YKfqYIx  ...      0.2160      0.00432          0.007230
# 2      6FZYc2BvF7tColxO8PBShV  ...      0.0341      0.68900          0.000000
# 3      37i9dQZF1DX4RDXswvP6Mj  ...      0.0409      0.03700          0.000000
# 4      4WiB26kw0INKwbzfb5M6Tv  ...      0.0550      0.28000          0.000000
# ...                       ...  ...         ...          ...               ...
# 13407  3hR2R6szlkwZeGyclTgHcF  ...      0.2860      0.00845          0.014300
# 13408  2bOjjgN1S3Gqd8vSMyafvJ  ...      0.0314      0.02200          0.000004
# 13409  6HaCi9bqaiuSZEDfCEmwyo  ...      0.3510      0.10100          0.000000
# 13410  6jI1gFr6ANFtT8MmTvA2Ux  ...      0.0878      0.00555          0.000000
# 13411  5EMARioe9z9eKOeWIAC2JW  ...      0.0270      0.71500          0.000428
#
#        liveness  valence    tempo  duration_ms  language  \
# 0        0.3470    0.404  135.225       373512        en
# 1        0.4890    0.650  111.904       262467        en
# 2        0.0664    0.405  118.593       243067        en
# 3        0.1380    0.240  130.018       193160        en
# 4        0.0975    0.305  147.764       224720        en
# ...         ...      ...      ...          ...       ...
# 13407    0.4850    0.368  194.055       207843        en
# 13408    0.3630    0.403  165.818       155714        en
# 13409    0.0919    0.340  154.962       179773        en
# 13410    0.3350    0.211  128.012       208656        en
# 13411    0.1150    0.657  142.218       191205        en
#
#                                         unique sentences  \
# 0      ['i feel alive', 'i thought', 'i loved you wit...
# 1      ['relationships they seem from the start', 'sl...
# 2      ['baby its cold outside', 'so nice and warm', ...
# 3      ['drippin 여기 주도권을', 'litty dumb', 'baby we go ...
# 4      ['i got you by my side', 'only we know where w...
# ...                                                  ...
# 13407  ['bubble butt busted in her throat', 'baby bab...
# 13408  ['i had to catch the bus', 'i was not prepared...
# 13409  ['i take a jet take a jet when', 'i think your...
# 13410  ['so lets take it take it now', 'we are reckle...
# 13411  ['bound bound', 'and the magic of her rare per...
#
#                                             clean lyrics
# 0      ['feel', 'alive', 'thought', 'loved', 'without...
# 1      ['relationships', 'seem', 'start', 'slick', 'b...
# 2      ['baby', 'cold', 'outside', 'nice', 'warm', 'l...
# 3      ['drippin', 'litty', 'dumb', 'baby', 'go', 'le...
# 4      ['got', 'side', 'know', 'going', 'distance', '...
# ...                                                  ...
# 13407  ['bubble', 'butt', 'busted', 'throat', 'baby',...
# 13408  ['catch', 'bus', 'prepared', 'let', 'go', 'dea...
# 13409  ['take', 'jet', 'think', 'girl', 'fell', 'love...
# 13410  ['lets', 'take', 'reckless', 'young', 'cause',...
# 13411  ['bound', 'magic', 'rare', 'personality', 'woo...
#
# [13412 rows x 27 columns]

# %%
movies_df[movies_df['track_name'] == 'The Passenger']
# Out:
#                      track_id     track_name               track_artist  \
# 3947   24FmdHoCr2jZGE6Z6dZbJT  The Passenger                   Iggy Pop
# 7241   3yP0cohcr97BUNJcgvmSVg  The Passenger                   Iggy Pop
# 11053  6EZDbjz2X5XzgIZCtbsrXh  The Passenger  Siouxsie and the Banshees
#
#                                                   lyrics  track_popularity  \
# 3947   ['i am a passenger', 'and', 'i ride and', 'i r...                45
# 7241   ['i am a passenger', 'and', 'i ride and', 'i r...                21
# 11053  ['i am the passenger', 'and', 'i ride and', 'i...                59
#
#                track_album_id  \
# 3947   5F79SWd4x7teHv5An2pqHQ
# 7241   7ynKEunH8LSit4TR3foMVC
# 11053  7kEqVGkLoruahp34YW16oe
#
#                                         track_album_name  \
# 3947                                       Lust For Life
# 7241                                       Lust For Life
# 11053  Through The Looking Glass (Remastered And Expa...
#
#       track_album_release_date            playlist_name  \
# 3947                1977-01-01  Intro to Permanent Wave
# 7241                1977-09-09   Workday: Rock Classics
# 11053               1987-03-02           Permanent Wave
#
#                   playlist_id  ... speechiness acousticness  instrumentalness  \
# 3947   3QGjcvI9hCZw81NqKq3ZGv  ...      0.0457       0.0797          0.000000
# 7241   37i9dQZF1DX1lwxXvReaux  ...      0.0457       0.0797          0.000000
# 11053  5Go0Jsxj1UnsU7Om841BEo  ...      0.0673       0.0309          0.000063
#
#        liveness  valence    tempo  duration_ms  language  \
# 3947      0.241    0.738  134.937       284067        en
# 7241      0.241    0.738  134.937       284067        en
# 11053     0.135    0.294  139.819       309307        en
#
#                                         unique sentences  \
# 3947   ['over the citys ripping sky', 'cause it just ...
# 7241   ['over the citys ripping sky', 'cause it just ...
# 11053  ['cause it just belongs to you and me', 'i see...
#
#                                             clean lyrics
# 3947   ['citys', 'ripping', 'sky', 'cause', 'belongs'...
# 7241   ['citys', 'ripping', 'sky', 'cause', 'belongs'...
# 11053  ['cause', 'belongs', 'see', 'stars', 'come', '...
#
# [3 rows x 27 columns]

# %%
movies_df[movies_df['track_name'] == 'Do Or Die - Afrojack vs. THIRTY SECONDS TO MARS Remix']
# Out:
#                     track_id  \
# 4550  2hr7myxuDCoXsKyVfh4ue0
# 6294  3i4SQvUfK8Un3YkraZwkNr
#
#                                              track_name track_artist  \
# 4550  Do Or Die - Afrojack vs. THIRTY SECONDS TO MAR...     Afrojack
# 6294  Do Or Die - Afrojack vs. THIRTY SECONDS TO MAR...     Afrojack
#
#                                                  lyrics  track_popularity  \
# 4550  ['in the middle of the night when the angels s...                55
# 6294  ['in the middle of the night when the angels s...                 0
#
#               track_album_id           track_album_name  \
# 4550  7G1441qDQeERZDyMipQPE8  Forget The World (Deluxe)
# 6294  2V0QrN19MlIEwcuV4SEwfl          Do Or Die (Remix)
#
#      track_album_release_date  \
# 4550               2014-01-01
# 6294               2014-01-01
#
#                                           playlist_name  \
# 4550      Mix ElectroPop//ElectroHouse// DeepHouse 2020
# 6294  big boom room — TOMORROWLAND EDC EDM BIG ROOM ...
#
#                  playlist_id  ... speechiness acousticness  instrumentalness  \
# 4550  23swqzpOZwW1NhPiZ7iyFI  ...      0.0416       0.0340          0.000003
# 6294  2oalsaFUockoPf1DU3wrL8  ...      0.0440       0.0335          0.000002
#
#       liveness  valence    tempo  duration_ms  language  \
# 4550     0.047    0.206  128.041       278174        en
# 6294     0.048    0.211  128.025       278174        en
#
#                                        unique sentences  \
# 4550  ['and the story goes on on on', 'you and', 'on...
# 6294  ['and the story goes on on on', 'you and', 'on...
#
#                                            clean lyrics
# 4550  ['story', 'goes', 'know', 'never', 'forget', '...
# 6294  ['story', 'goes', 'know', 'never', 'forget', '...
#
# [2 rows x 27 columns]

# %%
for x in ['drama']:
  print(x)
# Out:
# drama

# %%
for x in set([g for lst in movies_df['genre'] for g in lst]):
  print(x)
# Out:
# horror
#  crime
#  horror
#  western
# film-noir
# sci-fi
# adventure
# a
# mystery
#  thriller
#  sci-fi
#  comedy
#  romance
#  mystery
# family
# animation
# western
#  biography
# crime
#  sport
# thriller
#  fantasy
# action
#  war
# drama
#  musical
#  film-noir
# romance
# comedy
# n
#  action
#  drama
# fantasy
#  music
#  history
#  adventure
#  family
# biography
# musical

# %%
movies_df.to_csv('clean_movie_dataset.csv')

# %%
print(movies_df[movies_df['director'].str.lower() == "x"].empty)
# Out:
# True

# %%
nltk.edit_distance(["apple","apple"], ['word','juice'])
# Out:
# 2

# %%
nltk.edit_distance("apple", 'word')
# Out:
# 5

# %%
nltk.edit_distance("apple", 'juice')
# Out:
# 4

# %%
for x in [1,2,3,4,5,6]:
  print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
min([1,2,34])
# Out:
# 1
